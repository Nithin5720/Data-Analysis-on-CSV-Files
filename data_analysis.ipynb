# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Load CSV file
data = pd.read_csv("sales_data.csv")

# Step 3: Display first few rows
print("📊 Sample Data:")
print(data.head())

# Step 4: Add a 'Total_Sales' column
data["Total_Sales"] = data["Quantity"] * data["Price"]

# Step 5: Basic Insights
print("\n✅ Basic Information:")
print(data.info())

print("\n📈 Summary Statistics:")
print(data.describe())

# Step 6: Total sales by product
sales_by_product = data.groupby("Product")["Total_Sales"].sum()
print("\n💰 Total Sales by Product:")
print(sales_by_product)

# Step 7: Total sales by region
sales_by_region = data.groupby("Region")["Total_Sales"].sum()
print("\n🌍 Total Sales by Region:")
print(sales_by_region)

# Step 8: Plot the charts
plt.figure(figsize=(8,4))
sales_by_product.plot(kind='bar', color='skyblue')
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales (₹)")
plt.grid(True)
plt.show()

plt.figure(figsize=(8,4))
sales_by_region.plot(kind='bar', color='orange')
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales (₹)")
plt.grid(True)
plt.show()
# Out:
# 📊 Sample Data:
#          Date Region Product  Quantity  Price
# 0  2025-01-01  North  Laptop         4  60000
# 1  2025-01-02  South   Phone        10  15000
# 2  2025-01-03   East  Laptop         3  62000
# 3  2025-01-04   West  Tablet         5  20000
# 4  2025-01-05  North   Phone         8  14000
#
# ✅ Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         6 non-null      object
#  1   Region       6 non-null      object
#  2   Product      6 non-null      object
#  3   Quantity     6 non-null      int64
#  4   Price        6 non-null      int64
#  5   Total_Sales  6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 416.0+ bytes
# None
#
# 📈 Summary Statistics:
#         Quantity         Price    Total_Sales
# count   6.000000      6.000000       6.000000
# mean    5.333333  38666.666667  151666.666667
# std     3.076795  24557.415716   53117.479860
# min     2.000000  14000.000000  100000.000000
# 25%     3.250000  16250.000000  114500.000000
# 50%     4.500000  40000.000000  136000.000000
# 75%     7.250000  60750.000000  177000.000000
# max    10.000000  62000.000000  240000.000000
#
# 💰 Total Sales by Product:
# Product
# Laptop    548000
# Phone     262000
# Tablet    100000
# Name: Total_Sales, dtype: int64
#
# 🌍 Total Sales by Region:
# Region
# East     186000
# North    352000
# South    272000
# West     100000
# Name: Total_Sales, dtype: int64
